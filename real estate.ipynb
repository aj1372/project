# %% [markdown]
# ## Real Estate

# %%
import pandas as pd

# %%
housing = pd.read_csv("data.csv")

# %%
housing.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  Unnamed: 14 Unnamed: 15
# 0  396.90   9.14  21.6          NaN         NaN
# 1  392.83   4.03  34.7          NaN         NaN
# 2  394.63   2.94  33.4          NaN         NaN
# 3  396.90   5.33  36.2          NaN         NaN
# 4  394.12   5.21  28.7          NaN         NaN

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505 entries, 0 to 504
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CRIM         505 non-null    float64
#  1   ZN           505 non-null    float64
#  2   INDUS        505 non-null    float64
#  3   CHAS         505 non-null    int64
#  4   NOX          505 non-null    float64
#  5   RM           505 non-null    float64
#  6   AGE          505 non-null    float64
#  7   DIS          505 non-null    float64
#  8   RAD          505 non-null    int64
#  9   TAX          505 non-null    int64
#  10  PTRATIO      505 non-null    float64
#  11  B            505 non-null    float64
#  12  LSTAT        505 non-null    float64
#  13  MEDV         505 non-null    float64
#  14  Unnamed: 14  0 non-null      float64
#  15  Unnamed: 15  1 non-null      object
# dtypes: float64(12), int64(3), object(1)
# memory usage: 63.2+ KB

# %%
housing['CHAS'].value_counts()
# Out:
# 0    470
# 1     35
# Name: CHAS, dtype: int64

# %%
housing.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean     3.620667   11.350495   11.154257    0.069307    0.554728    6.284059
# std      8.608572   23.343704    6.855868    0.254227    0.115990    0.703195
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082210    0.000000    5.190000    0.000000    0.449000    5.885000
# 50%      0.259150    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  505.000000  505.000000  505.000000  505.000000  505.000000
# mean    68.581584    3.794459    9.566337  408.459406   18.461782  356.594376
# std     28.176371    2.107757    8.707553  168.629992    2.162520   91.367787
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.000000    2.100000    4.000000  279.000000   17.400000  375.330000
# 50%     77.700000    3.199200    5.000000  330.000000   19.100000  391.430000
# 75%     94.100000    5.211900   24.000000  666.000000   20.200000  396.210000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT        MEDV  Unnamed: 14
# count  505.000000  505.000000          0.0
# mean    12.668257   22.529901          NaN
# std      7.139950    9.205991          NaN
# min      1.730000    5.000000          NaN
# 25%      7.010000   17.000000          NaN
# 50%     11.380000   21.200000          NaN
# 75%     16.960000   25.000000          NaN
# max     37.970000   50.000000          NaN

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
housing.hist(bins=50, figsize=(20, 15))
# Out:
# array([[<AxesSubplot:title={'center':'CRIM'}>,
#         <AxesSubplot:title={'center':'ZN'}>,
#         <AxesSubplot:title={'center':'INDUS'}>,
#         <AxesSubplot:title={'center':'CHAS'}>],
#        [<AxesSubplot:title={'center':'NOX'}>,
#         <AxesSubplot:title={'center':'RM'}>,
#         <AxesSubplot:title={'center':'AGE'}>,
#         <AxesSubplot:title={'center':'DIS'}>],
#        [<AxesSubplot:title={'center':'RAD'}>,
#         <AxesSubplot:title={'center':'TAX'}>,
#         <AxesSubplot:title={'center':'PTRATIO'}>,
#         <AxesSubplot:title={'center':'B'}>],
#        [<AxesSubplot:title={'center':'LSTAT'}>,
#         <AxesSubplot:title={'center':'MEDV'}>,
#         <AxesSubplot:title={'center':'Unnamed: 14'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ## Train-Test Splitting

# %%
##
import numpy as np
def split_train_test(data, test_ratio):
    np.random.seed(42)
    shuffled = np.random.permutation(len(data))
    test_set_size = int(len(data) * test_ratio)
    test_indices = shuffled[:test_set_size]
    train_indices = shuffled[test_set_size:]
    return data.iloc[train_indices], data.iloc[test_indices]

# %%
#train_set, test_set = split_train_test(housing, 0.2)

# %%
#print(f"Rows in tran set: {len(train_set)}\nRows in test test: {len(test_set)}\n")

# %%
from sklearn.model_selection import train_test_split
train_set, test_set = train_test_split(housing, test_size=0.2, random_state=42)
print(f"Rows in tran set: {len(train_set)}\nRows in test test: {len(test_set)}\n")
# Out:
# Rows in tran set: 404
# Rows in test test: 101

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2,random_state=42)
for train_index, test_index in split.split(housing, housing['CHAS']):
    strat_train_set = housing.loc[train_index]
    strat_test_set = housing.loc[test_index]

# %%
strat_test_set.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean     3.380402   15.995050   10.547426    0.069307    0.544544    6.413772
# std      9.957745   27.945169    7.007952    0.255242    0.113916    0.747622
# min      0.010960    0.000000    0.460000    0.000000    0.389000    4.368000
# 25%      0.050230    0.000000    4.950000    0.000000    0.447000    5.963000
# 50%      0.178990    0.000000    8.140000    0.000000    0.515000    6.297000
# 75%      2.446680   21.000000   18.100000    0.000000    0.614000    6.750000
# max     88.976200   95.000000   27.740000    1.000000    0.871000    8.704000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  101.000000  101.000000  101.000000  101.000000  101.000000  101.000000
# mean    68.715842    3.858099    9.019802  396.584158   18.298020  368.881287
# std     27.263007    2.042402    8.538126  170.514707    2.338161   73.674238
# min      7.800000    1.316300    1.000000  188.000000   12.600000    2.520000
# 25%     45.700000    2.122400    4.000000  270.000000   16.800000  380.020000
# 50%     77.800000    3.317500    5.000000  307.000000   19.100000  393.680000
# 75%     91.900000    5.491700    8.000000  666.000000   20.200000  396.900000
# max    100.000000    8.696600   24.000000  711.000000   21.200000  396.900000
#
#             LSTAT        MEDV  Unnamed: 14
# count  101.000000  101.000000          0.0
# mean    12.008119   23.266337          NaN
# std      6.892168    9.405586          NaN
# min      2.970000    6.300000          NaN
# 25%      6.580000   18.500000          NaN
# 50%     10.260000   21.500000          NaN
# 75%     16.960000   27.000000          NaN
# max     30.630000   50.000000          NaN

# %% [markdown]
# ## Looking for Correlations

# %%
corr_matrix = housing.corr()

# %%
corr_matrix['MEDV'].sort_values(ascending=False)
# Out:
# MEDV           1.000000
# RM             0.695365
# ZN             0.360393
# B              0.333394
# DIS            0.249896
# CHAS           0.175364
# AGE           -0.376932
# RAD           -0.381690
# CRIM          -0.388249
# NOX           -0.427295
# TAX           -0.468543
# INDUS         -0.484126
# PTRATIO       -0.508411
# LSTAT         -0.738187
# Unnamed: 14         NaN
# Name: MEDV, dtype: float64

# %%
from pandas.plotting import scatter_matrix
attributes = ["RM", "ZN", "MEDV", "LSTAT"]
scatter_matrix(housing[attributes], figsize = (12,8))
# Out:
# array([[<AxesSubplot:xlabel='RM', ylabel='RM'>,
#         <AxesSubplot:xlabel='ZN', ylabel='RM'>,
#         <AxesSubplot:xlabel='MEDV', ylabel='RM'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='RM'>],
#        [<AxesSubplot:xlabel='RM', ylabel='ZN'>,
#         <AxesSubplot:xlabel='ZN', ylabel='ZN'>,
#         <AxesSubplot:xlabel='MEDV', ylabel='ZN'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='ZN'>],
#        [<AxesSubplot:xlabel='RM', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='ZN', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='MEDV', ylabel='MEDV'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='MEDV'>],
#        [<AxesSubplot:xlabel='RM', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='ZN', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='MEDV', ylabel='LSTAT'>,
#         <AxesSubplot:xlabel='LSTAT', ylabel='LSTAT'>]], dtype=object)

# %% [markdown]
# ## Attribute Combination

# %%
housing["TAXRM"] = housing['TAX']/housing['RM']

# %%
housing.head()
# Out:
#       CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.02731  0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 1  0.02729  0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 2  0.03237  0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 3  0.06905  0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
# 4  0.02985  0.0   2.18     0  0.458  6.430  58.7  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  Unnamed: 14 Unnamed: 15      TAXRM
# 0  396.90   9.14  21.6          NaN         NaN  37.688834
# 1  392.83   4.03  34.7          NaN         NaN  33.681280
# 2  394.63   2.94  33.4          NaN         NaN  31.723350
# 3  396.90   5.33  36.2          NaN         NaN  31.061984
# 4  394.12   5.21  28.7          NaN         NaN  34.525661

# %% [markdown]
# ## Scikit-learn Design
